# %%
cd .
# Out:
# C:\Users\hp\deeplearning

# %%
# !git init
# Out:
# Initialized empty Git repository in C:/Users/hp/deeplearning/.git/

# %%
# !git add .

# %%
# !git commit -m "Initial commits"
# Out:
# [master (root-commit) 6908b3c] Initial commits
#  5 files changed, 2730 insertions(+)
#  create mode 100644 .ipynb_checkpoints/Untitled-checkpoint.ipynb
#  create mode 100644 Untitled.ipynb
#  create mode 100644 perceptron/.ipynb_checkpoints/percepdemo-checkpoint.ipynb
#  create mode 100644 perceptron/percepdemo.ipynb
#  create mode 100644 perceptron/placement.csv

# %%
# !git remote add origin https://github.com/Rishabhjain2109/deeplearning.git

# %%
# !git branch -M main
# !git push -u origin main
# Out:
# branch 'main' set up to track 'origin/main'.
# To https://github.com/Rishabhjain2109/deeplearning.git
#  * [new branch]      main -> main

# %%
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean
